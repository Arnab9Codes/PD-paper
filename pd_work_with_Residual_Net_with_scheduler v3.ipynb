# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnab9Codes/PD-paper/blob/main/pd_work_with_Residual_Net_with_scheduler%20v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Initial Imports

# %matplotlib inline

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import random
from tqdm import tqdm_notebook as tqdm

#import lime
#import eli5
#import mlxtend
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(10)

# %%
pd_speech_features = pd.read_csv('/content/drive/My Drive/Paper work/Speech detection/pd_speech_features.csv')
new_header = pd_speech_features.iloc[0] 
pd_speech_features = pd_speech_features[1:]
pd_speech_features.columns = new_header 
pd_speech_features.head()
print('Shape of the matrix is :', pd_speech_features.shape)
# Out:
# Shape of the matrix is : (756, 755)

# %%
pd_speech_features.info() # Gives type of columns
pd_speech_features.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 1 to 756
# Columns: 755 entries, id to class
# dtypes: object(755)
# memory usage: 4.4+ MB
# 0        id gender  ... tqwt_kurtosisValue_dec_36 class
# count   756    756  ...                       756   756
# unique  252      2  ...                       754     2
# top      13      1  ...                   10.0693     1
# freq      3    390  ...                         2   564
#
# [4 rows x 755 columns]

# %%
pd_speech_features['patient/healthy count'] = 1
pd_speech_features.groupby('class').sum()/3
# Out:
# 0      patient/healthy count
# class
# 0                       64.0
# 1                      188.0

# %%
pd_speech_features = pd_speech_features.drop(['patient/healthy count'], axis = 1)  #756x755

# %%
pd_speech_features =  pd_speech_features.astype(float) #per default all floats 
pd_speech_features[['id', 'numPulses', 'numPeriodsPulses']] = pd_speech_features[['id', 'numPulses', 'numPeriodsPulses']].astype(int) #ints
pd_speech_features[['gender', 'class']] = pd_speech_features[['gender', 'class']].astype('category') #categoricals
pd_speech_features.dtypes
# Out:
# 0
# id                              int64
# gender                       category
# PPE                           float64
# DFA                           float64
# RPDE                          float64
#                                ...
# tqwt_kurtosisValue_dec_33     float64
# tqwt_kurtosisValue_dec_34     float64
# tqwt_kurtosisValue_dec_35     float64
# tqwt_kurtosisValue_dec_36     float64
# class                        category
# Length: 755, dtype: object

# %%
pd_speech_features_no_tqwt = pd_speech_features[pd_speech_features.columns[1: -433]]
pd_speech_features_no_tqwt.head()
# Out:
# 0 gender      PPE  ...  app_LT_TKEO_std_9_coef  app_LT_TKEO_std_10_coef
# 1    1.0  0.85247  ...               4188.2456                8373.9278
# 2    1.0  0.76686  ...               4148.9889                8298.1606
# 3    1.0  0.85083  ...               4127.0967                8254.7868
# 4    0.0  0.41121  ...               3910.7029                7698.9389
# 5    0.0  0.32790  ...               4297.4639                8645.2845
#
# [5 rows x 321 columns]

# %%
train_df=pd_speech_features
train_df_tqwt=pd_speech_features_no_tqwt

y_train = train_df['class']
y_train = np.array(y_train.values, dtype = 'int')
x_train = train_df.drop(['class','id'], axis = 1) 

x_train = x_train.values
#y_validation = validation_df['class']
#y_validation = np.array(y_validation.values, dtype = 'int')
#x_validation = validation_df.drop(['class'], axis = 1)

# %%
features=train_df.columns.values.tolist()
features.remove('id')
features.remove('class')
print(len(features))
# Out:
# 753

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (756, 753)
# (756,)

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.24.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.1.0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train= sc.fit_transform(x_train)

# %%
from sklearn.feature_selection import SequentialFeatureSelector
sfs_9 = SequentialFeatureSelector(LogisticRegression(random_state=10),n_features_to_select=9, n_jobs=-1)

sfs_9=sfs_9.fit(x_train, y_train)

# %%
x_train_transformed_9_features=sfs_9.transform(x_train)
x_train_transformed_9_features.shape
# Out:
# (756, 9)

# %% [markdown]
# # LSTM

# %%
from sklearn.model_selection import LeaveOneOut, KFold
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
from sklearn import svm 
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import classification_report


param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}

# %%
k_fold=KFold(10,True,10)

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
torch.manual_seed(10)

# %%
m=nn.Sequential(nn.Linear(18,18), nn.ReLU(),nn.Linear(18,18),nn.ReLU())

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1=nn.Linear(9,18)
        self.l2=nn.Linear(18,18)
        self.l3=nn.Linear(18,18)
        self.ll=m
        self.l4=nn.Linear(18,1)
        
    def forward(self,x):
        x=self.l1(x)
        x=F.relu(F.dropout(x,0.20))
        x1=self.l2(x)
        #x2=F.relu(F.dropout(x1,0.20))
        x=self.l3(x)
        x=self.ll((x+x1)/2.00)
        x=F.relu(F.dropout(x,0.20))
        #x3=self.ll((x))
        x=self.l3(x)
        x=F.relu(F.dropout((x+x1)/2.0,0.00))
        x=self.l4(x)
        
        return x

# %%
#x=torch.from_numpy(x_train_transformed_9_features[:600]).float()
#x=torch.from_numpy(x_train[:600]).float()
#y=torch.from_numpy(y_train[:600]).float()

def train(model,optimizer, scheduler, criterion, x,y):
    
    losses=[]
    
    for i in range(200):
        output=model(x)
        loss=criterion(output.view(y.shape[0]),y)
    
        losses.append(loss)
    
        #if (i%100==0):
         #   print(i,' ',loss.item())
    
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
    
    # training accuracy
    with torch.no_grad():
        preds=torch.sigmoid(model(x)).round()
        print('\ntraining report: \n',classification_report(preds.view(preds.shape[0]),y))
        
    return model, losses

#model, losses= train(model,optimizer, scheduler, criterion,x,y)

# %%
def test(model, tstx, tsty):
    with torch.no_grad():
    
        preds=torch.sigmoid(model(tstx)).round()
        print('testing report:')
        print(classification_report(preds.view(preds.shape[0]), tsty))
        print(torch.sigmoid(preds).round().shape)

# %%
#tstx=torch.from_numpy(x_train_transformed_9_features[600:]).float()
#tstx=torch.from_numpy(x_train[600:]).float()
tsty=torch.from_numpy(y_train[600:]).float()

#test(model,tstx,tsty)

# %%
def run_network(model, trainx,trainy, testx, testy):
    model=Model()
    criterion = nn.BCEWithLogitsLoss()
    optimizer=torch.optim.SGD(model.parameters(),lr=0.6,momentum=0.99, nesterov=True)
    #optim=torch.optim.Adam(model.parameters(),lr=0.1)
    scheduler=torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.3)
    model, losses= train(model,optimizer, scheduler, criterion,trainx, trainy)
    test(model, testx, testy)
    
    return model, losses

# %%
fold=0
losses=[[] for i in range(10)]

for trids, tstids in k_fold.split(x_train_transformed_9_features):
    trainx, testx=x_train_transformed_9_features[trids,:], x_train_transformed_9_features[tstids,:]
    #trainx, testx=x_train[trids,:], x_train[tstids,:]
    trainy, testy=y_train[trids], y_train[tstids]
    
    trainx=torch.from_numpy(trainx).float()
    trainy=torch.from_numpy(trainy).float()
    testx=torch.from_numpy(testx).float()
    testy=torch.from_numpy(testy).float()
    
    print('fold: ',fold)
    
    model=Model()
    
    _,losses[fold]=run_network(model, trainx,trainy, testx,testy)
    
    fold=fold+1
# Out:
# fold:  0
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.52      0.85      0.65       110
#          1.0       0.97      0.85      0.90       570
#
#     accuracy                           0.85       680
#    macro avg       0.74      0.85      0.78       680
# weighted avg       0.89      0.85      0.86       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.62      0.45         8
#          1.0       0.95      0.87      0.91        68
#
#     accuracy                           0.84        76
#    macro avg       0.65      0.75      0.68        76
# weighted avg       0.89      0.84      0.86        76
#
# torch.Size([76, 1])
# fold:  1
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.49      0.82      0.61       102
#          1.0       0.96      0.85      0.90       578
#
#     accuracy                           0.84       680
#    macro avg       0.73      0.84      0.76       680
# weighted avg       0.89      0.84      0.86       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.70      0.47        10
#          1.0       0.95      0.80      0.87        66
#
#     accuracy                           0.79        76
#    macro avg       0.65      0.75      0.67        76
# weighted avg       0.87      0.79      0.82        76
#
# torch.Size([76, 1])
# fold:  2
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.47      0.84      0.60        96
#          1.0       0.97      0.84      0.90       584
#
#     accuracy                           0.84       680
#    macro avg       0.72      0.84      0.75       680
# weighted avg       0.90      0.84      0.86       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.82      0.62        11
#          1.0       0.97      0.86      0.91        65
#
#     accuracy                           0.86        76
#    macro avg       0.73      0.84      0.77        76
# weighted avg       0.90      0.86      0.87        76
#
# torch.Size([76, 1])
# fold:  3
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.48      0.84      0.61       100
#          1.0       0.97      0.84      0.90       580
#
#     accuracy                           0.84       680
#    macro avg       0.73      0.84      0.76       680
# weighted avg       0.90      0.84      0.86       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.83      0.67        12
#          1.0       0.97      0.88      0.92        64
#
#     accuracy                           0.87        76
#    macro avg       0.76      0.85      0.79        76
# weighted avg       0.90      0.87      0.88        76
#
# torch.Size([76, 1])
# fold:  4
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.50      0.84      0.62       105
#          1.0       0.97      0.85      0.90       575
#
#     accuracy                           0.84       680
#    macro avg       0.73      0.84      0.76       680
# weighted avg       0.89      0.84      0.86       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.47      1.00      0.64         7
#          1.0       1.00      0.88      0.94        69
#
#     accuracy                           0.89        76
#    macro avg       0.73      0.94      0.79        76
# weighted avg       0.95      0.89      0.91        76
#
# torch.Size([76, 1])
# fold:  5
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.50      0.84      0.62       101
#          1.0       0.97      0.85      0.91       579
#
#     accuracy                           0.85       680
#    macro avg       0.73      0.85      0.77       680
# weighted avg       0.90      0.85      0.86       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.90      0.58        10
#          1.0       0.98      0.82      0.89        66
#
#     accuracy                           0.83        76
#    macro avg       0.71      0.86      0.74        76
# weighted avg       0.91      0.83      0.85        76
#
# torch.Size([76, 1])
# fold:  6
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.47      0.80      0.59        97
#          1.0       0.96      0.85      0.90       584
#
#     accuracy                           0.84       681
#    macro avg       0.72      0.83      0.75       681
# weighted avg       0.89      0.84      0.86       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.87      0.63        15
#          1.0       0.96      0.78      0.86        60
#
#     accuracy                           0.80        75
#    macro avg       0.73      0.82      0.75        75
# weighted avg       0.87      0.80      0.82        75
#
# torch.Size([75, 1])
# fold:  7
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.50      0.85      0.63       105
#          1.0       0.97      0.85      0.90       576
#
#     accuracy                           0.85       681
#    macro avg       0.73      0.85      0.77       681
# weighted avg       0.90      0.85      0.86       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.60      0.50        10
#          1.0       0.93      0.88      0.90        65
#
#     accuracy                           0.84        75
#    macro avg       0.68      0.74      0.70        75
# weighted avg       0.87      0.84      0.85        75
#
# torch.Size([75, 1])
# fold:  8
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.47      0.86      0.61        95
#          1.0       0.97      0.84      0.90       586
#
#     accuracy                           0.85       681
#    macro avg       0.72      0.85      0.76       681
# weighted avg       0.90      0.85      0.86       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.71      0.61        14
#          1.0       0.93      0.85      0.89        61
#
#     accuracy                           0.83        75
#    macro avg       0.73      0.78      0.75        75
# weighted avg       0.85      0.83      0.84        75
#
# torch.Size([75, 1])
# fold:  9
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.45      0.81      0.58        93
#          1.0       0.97      0.85      0.90       588
#
#     accuracy                           0.84       681
#    macro avg       0.71      0.83      0.74       681
# weighted avg       0.90      0.84      0.86       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.84      0.70        19
#          1.0       0.94      0.80      0.87        56
#
#     accuracy                           0.81        75
#    macro avg       0.77      0.82      0.78        75
# weighted avg       0.85      0.81      0.82        75
#
# torch.Size([75, 1])

# %%
plt.figure(figsize=(15,6))
for i in range(10):
  plt.plot(losses[i],label='fold'+str(i))
plt.title('losses')
plt.legend(loc='upper_right')
plt.ylim(0.25,.8)
# Out:
# (0.25, 0.8)
