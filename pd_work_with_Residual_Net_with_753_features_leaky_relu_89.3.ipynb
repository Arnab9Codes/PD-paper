# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnab9Codes/PD-paper/blob/main/pd_work_with_Residual_Net_with_753_features_leaky_relu_89.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Initial Imports

# %matplotlib inline

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import random
from tqdm import tqdm_notebook as tqdm

#import lime
#import eli5
#import mlxtend
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(10)

# %%
pd_speech_features = pd.read_csv('/content/drive/My Drive/Paper work/Speech detection/pd_speech_features.csv')
new_header = pd_speech_features.iloc[0] 
pd_speech_features = pd_speech_features[1:]
pd_speech_features.columns = new_header 
pd_speech_features.head()
print('Shape of the matrix is :', pd_speech_features.shape)
# Out:
# Shape of the matrix is : (756, 755)

# %%
pd_speech_features.info() # Gives type of columns
pd_speech_features.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 1 to 756
# Columns: 755 entries, id to class
# dtypes: object(755)
# memory usage: 4.4+ MB
# 0        id gender  ... tqwt_kurtosisValue_dec_36 class
# count   756    756  ...                       756   756
# unique  252      2  ...                       754     2
# top     185      1  ...                   10.0693     1
# freq      3    390  ...                         2   564
#
# [4 rows x 755 columns]

# %%
pd_speech_features['patient/healthy count'] = 1
pd_speech_features.groupby('class').sum()/3
# Out:
# 0      patient/healthy count
# class
# 0                       64.0
# 1                      188.0

# %%
pd_speech_features = pd_speech_features.drop(['patient/healthy count'], axis = 1)  #756x755

# %%
pd_speech_features =  pd_speech_features.astype(float) #per default all floats 
pd_speech_features[['id', 'numPulses', 'numPeriodsPulses']] = pd_speech_features[['id', 'numPulses', 'numPeriodsPulses']].astype(int) #ints
pd_speech_features[['gender', 'class']] = pd_speech_features[['gender', 'class']].astype('category') #categoricals
pd_speech_features.dtypes
# Out:
# 0
# id                              int64
# gender                       category
# PPE                           float64
# DFA                           float64
# RPDE                          float64
#                                ...
# tqwt_kurtosisValue_dec_33     float64
# tqwt_kurtosisValue_dec_34     float64
# tqwt_kurtosisValue_dec_35     float64
# tqwt_kurtosisValue_dec_36     float64
# class                        category
# Length: 755, dtype: object

# %%
pd_speech_features_no_tqwt = pd_speech_features[pd_speech_features.columns[1: -433]]
pd_speech_features_no_tqwt.head()
# Out:
# 0 gender      PPE  ...  app_LT_TKEO_std_9_coef  app_LT_TKEO_std_10_coef
# 1    1.0  0.85247  ...               4188.2456                8373.9278
# 2    1.0  0.76686  ...               4148.9889                8298.1606
# 3    1.0  0.85083  ...               4127.0967                8254.7868
# 4    0.0  0.41121  ...               3910.7029                7698.9389
# 5    0.0  0.32790  ...               4297.4639                8645.2845
#
# [5 rows x 321 columns]

# %%
train_df=pd_speech_features
train_df_tqwt=pd_speech_features_no_tqwt

y_train = train_df['class']
y_train = np.array(y_train.values, dtype = 'int')
x_train = train_df.drop(['class','id'], axis = 1) 

x_train = x_train.values
#y_validation = validation_df['class']
#y_validation = np.array(y_validation.values, dtype = 'int')
#x_validation = validation_df.drop(['class'], axis = 1)

# %%
features=train_df.columns.values.tolist()
features.remove('id')
features.remove('class')
print(len(features))
# Out:
# 753

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (756, 753)
# (756,)

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.24.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train= sc.fit_transform(x_train)

# %%
from sklearn.model_selection import LeaveOneOut, KFold
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
k_fold=KFold(10,True,10)

# %% [markdown]
# # ResidualNet

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
torch.manual_seed(10)

# %%
x_train.shape
# Out:
# (756, 753)

# %%
HU=50
m=nn.Sequential(nn.Linear(HU,HU), nn.LeakyReLU(),nn.Linear(HU,HU),nn.LeakyReLU())

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1=nn.Linear(753,HU)
        self.bn=nn.BatchNorm1d(HU)
        self.l2=nn.Linear(HU,HU)
        self.l3=nn.Linear(HU,HU)
        self.ll=m
        self.l4=nn.Linear(HU,1)
        
    def forward(self,x):
        x=self.l1(x)
        x=F.leaky_relu(F.dropout(x,0.20))
        x1=self.l2(x)
        #x2=F.relu(F.dropout(x1,0.20))
        #x1=bn(x1)
        x=self.l3(x1)
        x2=self.ll((x+x1)/2.00)
        x=F.leaky_relu(F.dropout(x2,0.20))
        x=self.ll((x))
        #x=self.l3(x)
        x3=F.leaky_relu(F.dropout((x+x1+x2)/3.0,0.200))
        x=self.l4(x3)
        
        return x

# %%
#x=torch.from_numpy(x_train_transformed_9_features[:600]).float()
x=torch.from_numpy(x_train[:600]).float()
y=torch.from_numpy(y_train[:600]).float()

def train(model,optimizer, scheduler, criterion, x,y):
    
    losses=[]
    
    for i in range(200):
        output=model(x)
        loss=criterion(output.view(y.shape[0]),y)
    
        losses.append(loss)
    
        #if (i%10==0):
           # print(i,' ',loss.item())
    
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()
    
    # training accuracy
    with torch.no_grad():
        preds=torch.sigmoid(model(x)).round()
        print('\ntraining report: \n',classification_report(preds.view(preds.shape[0]),y))
        
    return model, losses

#model, losses= train(model,optimizer, scheduler, criterion,x,y)

# %%
model=Model()
criterion = nn.BCEWithLogitsLoss()
optimizer=torch.optim.SGD(model.parameters(),lr=0.6,momentum=0.99, nesterov=True)
#optimizer=torch.optim.Adam(model.parameters(),lr=0.016)
scheduler=torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=.23)
model, losses= train(model,optimizer, scheduler, criterion,x, y)
# Out:
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00       142
#          1.0       1.00      1.00      1.00       458
#
#     accuracy                           1.00       600
#    macro avg       1.00      1.00      1.00       600
# weighted avg       1.00      1.00      1.00       600

# %%
plt.plot(losses)

# %%
def test(model, tstx, tsty):
    
    model.eval()
    with torch.no_grad():
    
        preds=torch.sigmoid(model(tstx)).round()
        print('testing report:')
        print(classification_report(preds.view(preds.shape[0]), tsty))
        print(torch.sigmoid(preds).round().shape)

# %%
tstx=torch.from_numpy(x_train[600:]).float()
tsty=torch.from_numpy(y_train[600:]).float()
test(model, tstx, tsty)
# Out:
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.66      0.61        44
#          1.0       0.86      0.80      0.83       112
#
#     accuracy                           0.76       156
#    macro avg       0.71      0.73      0.72       156
# weighted avg       0.78      0.76      0.77       156
#
# torch.Size([156, 1])

# %%
def run_network(model, trainx,trainy, testx, testy):
    model=Model()
    criterion = nn.BCEWithLogitsLoss()
    optimizer=torch.optim.SGD(model.parameters(),lr=0.4,momentum=0.99, nesterov=True)
    #optimizer=torch.optim.Adam(model.parameters(),lr=0.018)
    scheduler=torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=.23)
    model, losses= train(model,optimizer, scheduler, criterion,trainx, trainy)
    test(model, testx, testy)
    
    return model, losses

# %%
fold=0
losses=[[] for i in range(10)]

for trids, tstids in k_fold.split(x_train):
    trainx, testx=x_train[trids,:], x_train[tstids,:]
    #trainx, testx=x_train[trids,:], x_train[tstids,:]
    trainy, testy=y_train[trids], y_train[tstids]
    
    trainx=torch.from_numpy(trainx).float()
    trainy=torch.from_numpy(trainy).float()
    testx=torch.from_numpy(testx).float()
    testy=torch.from_numpy(testy).float()
    
    print('fold: ',fold)
    
    model=Model()
    
    _,losses[fold]=run_network(model, trainx,trainy, testx,testy)
    
    fold=fold+1
# Out:
# fold:  0
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       178
#          1.0       1.00      1.00      1.00       502
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.88      0.64         8
#          1.0       0.98      0.90      0.94        68
#
#     accuracy                           0.89        76
#    macro avg       0.74      0.89      0.79        76
# weighted avg       0.93      0.89      0.91        76
#
# torch.Size([76, 1])
# fold:  1
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       172
#          1.0       1.00      1.00      1.00       508
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65        20
#          1.0       0.88      0.88      0.88        56
#
#     accuracy                           0.82        76
#    macro avg       0.76      0.76      0.76        76
# weighted avg       0.82      0.82      0.82        76
#
# torch.Size([76, 1])
# fold:  2
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       174
#          1.0       1.00      1.00      1.00       506
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.81      0.76        16
#          1.0       0.95      0.92      0.93        60
#
#     accuracy                           0.89        76
#    macro avg       0.84      0.86      0.85        76
# weighted avg       0.90      0.89      0.90        76
#
# torch.Size([76, 1])
# fold:  3
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       174
#          1.0       1.00      1.00      1.00       506
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.93      0.85        15
#          1.0       0.98      0.93      0.96        61
#
#     accuracy                           0.93        76
#    macro avg       0.88      0.93      0.90        76
# weighted avg       0.94      0.93      0.94        76
#
# torch.Size([76, 1])
# fold:  4
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       177
#          1.0       1.00      1.00      1.00       503
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.79      0.76        14
#          1.0       0.95      0.94      0.94        62
#
#     accuracy                           0.91        76
#    macro avg       0.84      0.86      0.85        76
# weighted avg       0.91      0.91      0.91        76
#
# torch.Size([76, 1])
# fold:  5
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       171
#          1.0       1.00      1.00      1.00       509
#
#     accuracy                           1.00       680
#    macro avg       1.00      1.00      1.00       680
# weighted avg       1.00      1.00      1.00       680
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.71      0.71        21
#          1.0       0.89      0.89      0.89        55
#
#     accuracy                           0.84        76
#    macro avg       0.80      0.80      0.80        76
# weighted avg       0.84      0.84      0.84        76
#
# torch.Size([76, 1])
# fold:  6
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       166
#          1.0       1.00      1.00      1.00       515
#
#     accuracy                           1.00       681
#    macro avg       1.00      1.00      1.00       681
# weighted avg       1.00      1.00      1.00       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.90      0.81        21
#          1.0       0.96      0.87      0.91        54
#
#     accuracy                           0.88        75
#    macro avg       0.84      0.89      0.86        75
# weighted avg       0.90      0.88      0.88        75
#
# torch.Size([75, 1])
# fold:  7
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       178
#          1.0       1.00      1.00      1.00       503
#
#     accuracy                           1.00       681
#    macro avg       1.00      1.00      1.00       681
# weighted avg       1.00      1.00      1.00       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.88      0.93        16
#          1.0       0.97      1.00      0.98        59
#
#     accuracy                           0.97        75
#    macro avg       0.98      0.94      0.96        75
# weighted avg       0.97      0.97      0.97        75
#
# torch.Size([75, 1])
# fold:  8
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00       172
#          1.0       1.00      1.00      1.00       509
#
#     accuracy                           1.00       681
#    macro avg       1.00      1.00      1.00       681
# weighted avg       1.00      1.00      1.00       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.78      0.76        18
#          1.0       0.93      0.91      0.92        57
#
#     accuracy                           0.88        75
#    macro avg       0.83      0.85      0.84        75
# weighted avg       0.88      0.88      0.88        75
#
# torch.Size([75, 1])
# fold:  9
#
# training report:
#                precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00       164
#          1.0       1.00      1.00      1.00       517
#
#     accuracy                           1.00       681
#    macro avg       1.00      1.00      1.00       681
# weighted avg       1.00      1.00      1.00       681
#
# testing report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.84      0.90        31
#          1.0       0.90      0.98      0.93        44
#
#     accuracy                           0.92        75
#    macro avg       0.93      0.91      0.92        75
# weighted avg       0.92      0.92      0.92        75
#
# torch.Size([75, 1])

# %%
plt.figure(figsize=(15,6))
for i in range(10):
  plt.plot(losses[i],label='fold'+str(i))
plt.title('losses')
plt.legend(loc='upper_right')
#plt.ylim(0.0,.4)

# %%
plt.figure(figsize=(10,6))
for i in [1,3,7,8]:
  plt.plot(losses[i],label='fold'+str(i))
plt.title('losses')
plt.legend(loc='upper_right')
#plt.ylim(0.2,.8)
